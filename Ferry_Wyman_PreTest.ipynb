# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statistics as st

# %%
df = pd.read_csv('D:\Chapter 5\DSA\churn.csv',encoding = 'latin1')

# %%
df.head (5)
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
# 3     35              84        408          2510                   1
# 4     36              75        415           155                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              166.7              113
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
# state                            5000 non-null int64
# account_length                   5000 non-null int64
# area_code                        5000 non-null int64
# phone_number                     5000 non-null int64
# international_plan               5000 non-null int64
# voice_mail_plan                  5000 non-null int64
# number_vmail_messages            5000 non-null int64
# total_day_minutes                5000 non-null float64
# total_day_calls                  5000 non-null int64
# total_day_charge                 5000 non-null float64
# total_eve_minutes                5000 non-null float64
# total_eve_calls                  5000 non-null int64
# total_eve_charge                 5000 non-null float64
# total_night_minutes              5000 non-null float64
# total_night_calls                5000 non-null int64
# ...

# %%
st.mean(df.total_day_minutes)
# Out:
# 180.2889

# %%
st.mean(df.total_day_calls)
# Out:
# 100.0294

# %%
len(df['area_code'].unique())
# Out:
# 3

# %%
df['international_plan'].value_counts()
# Out:
# 0    4527
# 1     473
# Name: international_plan, dtype: int64

# %%
df['class'].value_counts()
# Out:
# 0    4293
# 1     707
# Name: class, dtype: int64

# %%
df.groupby('area_code').mean()[['class']]
# Out:
#               class
# area_code
# 408        0.140588
# 415        0.138677
# 510        0.147673

# %%
df.groupby('international_plan').mean()[['class']]
# Out:
#                        class
# international_plan
# 0                   0.112216
# 1                   0.420719

# %%
df.groupby('number_customer_service_calls').mean()[['class']]
# Out:
#                                   class
# number_customer_service_calls
# 0                              0.118280
# 1                              0.106383
# 2                              0.108252
# 3                              0.109774
# 4                              0.440476
# 5                              0.604167
# 6                              0.647059
# 7                              0.538462
# 8                              0.500000
# 9                              1.000000

# %%
df2 = df.drop ('area_code', axis=1, inplace=True)

# %%
df2 = df.drop ('account_length', axis=1, inplace=True)

# %%
df2 = df.drop ('phone_number', axis=1, inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn
sns.set (font_scale = 1.0)
fig, ax = plt.subplots(figsize=(20,20))
seaborn.heatmap(df.corr(), ax=ax, annot = True, fmt='.1g', square = True)
plt.show()
